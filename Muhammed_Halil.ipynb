# %% [markdown]
# # ph21: HWK 1
# In this assignment, we will get Buoy data from the NDBC and then use it to make some estimates about the future.
#
# ### Familiarize yourself
#
# We will be using data from the National Data Buoy Center (NDBC). Visit the NDBC website, https://www.ndbc.noaa.gov, and access some historical data. Take a look at the URL for the data you have accessed: you will need this format to access the data from python.
#
# ### Part 1: Getting the data
#
# You will need to save all necessary for your second part here. The following steps are for reference.
#
# 1. Use the `requests` library (or any other similar library at your choice) to download historical Buoy data
# 3. Save all data you downloaded into (a) file(s). If you feel like it, only save that part that is relevant for your second part.
# 4. Use a html parser library (e.g., `BeautifulSoup`, `lxml`, or `html5lib`) to extract the meaning of the data (i.e. what is it measuring and what are the units?). Also save this information somewhere.
# 5. From now on, you don't need to make any more requests to the NDBC website. Only use the data you downloaded.
#
#
# ### Part 2: Processing the data
# 6. (Optional) use the `pandas` library to read the data and process as needed, and save the processed data if you want to. Save the processed data
# 7. plot the oceant temperatures (`WTMP`), wave heights (`WVHT`), average wave periods (`APD`), and wind speeds (`WSPD`) going back 10 years or so (some buoys don't have all the data every year)
# 8. Look through `scipy.stats` and choose something like Pearson's or Spearman's correlation test. Determine what (if any) correlations you find between mean ocean temperatures and maximum wave heights or wave periods.

# %% [markdown]
# ### All written codes are only here for reference. You can also modify them if you want to.

# %% [markdown]
# # Part 1

# %%
# Libraries you might want to use
# Uncomment the ones you need
from datetime import datetime
from io import StringIO
from pathlib import Path
import csv 
import requests
from requests import Session
# from curl_cffi.requests import Session, AsyncSession

from bs4 import BeautifulSoup
import matplotlib.dates as mdates
# from lxml import html

from matplotlib import pyplot as plt
# import seaborn as sns

import pandas as pd
# import numpy as np
from scipy.stats import pearsonr

import yaml
#from tqdm import tqdm
import glob

# %%
# Prepare requests session. Let's pretend we are Chrome 118 here

# Think: In some cases, we can still be blocked as been flagged as bot at the first request.
#        Can you guess how the server knows it? (ignore javascript for now)

sess = Session()
sess.headers.update({'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/118.0.0.0 Safari/537.36'})

# Think: What's the difference between using requests.get() and sess.get()?

# %%
# Where to save the fetched data
path = Path('./Data')
path.mkdir(exist_ok=True)
url_template = 'https://www.ndbc.noaa.gov/view_text_file.php?filename={buoy_id}h{year}.txt.gz&dir=data/historical/stdmet/'
description_page_url = 'https://www.ndbc.noaa.gov/faq/measdes.shtml'

# %%
# Load the config file
with open('config.yaml') as f:
    config = yaml.safe_load(f)

buoy_ids:list[int] = config['buoys'] # We only use these id's for this assignment
head_columns:list[str] = config['columns'] # Data columns we want to keep. You may add more if you want

# %%
# An example of how to fetch the description and put it in a pd.DataFrame

r = sess.get(url_template.format(buoy_id=41010, year=2022))
r.raise_for_status()
buf= StringIO(r.text)
df = pd.read_csv(buf, sep=r'\s+', skiprows=[1])

# %% [markdown]
# Take a look:

# %%
df.head()
# Out:
#     #YY  MM  DD  hh  mm  WDIR  WSPD  GST   WVHT    DPD   APD  MWD    PRES  \
# 0  2022   1   1   0   0   222   1.1  1.5  99.00  99.00  99.0  999  1019.6
# 1  2022   1   1   0  10   212   1.5  1.9  99.00  99.00  99.0  999  1019.7
# 2  2022   1   1   0  20   208   1.4  1.9  99.00  99.00  99.0  999  1019.6
# 3  2022   1   1   0  30   204   1.4  1.9  99.00  99.00  99.0  999  1019.7
# 4  2022   1   1   0  40   205   1.3  1.9   0.62  13.79   4.6   28  1019.8
#
#    ATMP  WTMP  DEWP   VIS  TIDE
# 0  24.9  25.2  20.6  99.0  99.0
# 1  24.9  25.2  20.5  99.0  99.0
# 2  24.9  25.2  20.4  99.0  99.0
# 3  24.9  25.2  20.5  99.0  99.0
# 4  24.9  25.1  20.6  99.0  99.0

# %% [markdown]
# Now, your task here is:
# 1. For each buoy_id, generate all urls pointing to its data, and fetch&save the data. If the data is missing (`status_code`=404), skip it.
# 2. Save everything in raw, or any processed form that you see fits.
# 3. If the file is already downloaded, don't download it again. Just skip it here.
#
# Learn more about http status codes here:
# - https://en.wikipedia.org/wiki/List_of_HTTP_status_codes
# - https://http.cat/
#
# Two important ones here for today:
# - 200: OK; everything's alright
# - 404: Not Found; the file is missing

# %%
# ================ INSERT YOUR CODE HERE ================
for b_id in buoy_ids:
    for b_year in range(2014,2025):
        try:
            r = sess.get(url_template.format(buoy_id=b_id, year=b_year))
            r.raise_for_status()
            buf= StringIO(r.text)
            df = pd.read_csv(buf,sep=r'\s+', skiprows=[1])
            folder = Path(f'./Data/buoy_{b_id}')
            folder.mkdir(exist_ok=True)
            if not (path/f'./Data/buoy_{b_id}/buoy_{b_id}_{b_year}.csv').exists():
                df.to_csv(f'./Data/buoy_{b_id}/buoy_{b_id}_{b_year}.csv',index=False,columns=head_columns)
        except requests.exceptions.HTTPError as e:
            if r.status_code == 404:
                with open('./Data/missing_data.txt','a') as file:
                    file.write(f'{b_id} : {b_year}\n')
            continue

# %% [markdown]
# Though the units for all quantities are included in the data files received already, lets also try get them again from the website along with the description for each columns by parsing htmls.
#
# All information of our interest is available at [`description_page`](https://www.ndbc.noaa.gov/faq/measdes.shtml#stdmet).
#
# Your task is to:
#
# 1. Get a dictionary of all the quantity name and its unit
# 2. Get a dictionary of all the quantity name and its description
#
# To achieve this, you may want to use some html parser library, such as `BeautifulSoup`, `lxml`, or `html5lib`. If you really feel like it, you can also use regex just for fun like the good old days.
#
# Tip: Having no idea where to start? Try to open the [`description_page`](https://www.ndbc.noaa.gov/faq/measdes.shtml#stdmet) in your browser, and use the `inspect` tool (F12, or Ctrl+Shift+I) to see how the html is structured and locate the part of your interest. Pasting a copy of the html to some LLM and ask it how to extract the information you want may also be a good idea.
#
# Another Tip: Something called [`xpath`](https://en.wikipedia.org/wiki/XPath) may be extremely useful here. It can be access with `lxml`.

# %%
r = sess.get(description_page_url)
r.raise_for_status()
html_text = r.text # raw html text for your input

# %%
# ================ INSERT YOUR CODE HERE ================
dsc = BeautifulSoup(html_text,'html')
units = {}
meaning = {}

# parsing all glossaries except for the last one (exluding abbreviation list) 

for dl in dsc.find_all('dl')[0:-1]:
    for element in dl.find_all(['dt', 'dd']):
        if element.name == 'dt':
            meaning[element.get_text(strip=True)]=''
            last_key = element.get_text(strip=True)
        elif element.name == 'dd':
            meaning[last_key] = element.get_text()
            
for pre in dsc.find_all('pre'):
    units_loc = pre.get_text().find('#',2)
    if units_loc == -1:
        continue
    names = pre.get_text()[2:units_loc]
    names = names.split()
    unts_str = pre.get_text()[units_loc+1:]
    unts_lst = unts_str.split(maxsplit=len(names))[:-1]
    for i in range(len(names)):
        if names[i] not in units.keys():
            units[names[i]]=unts_lst[i]

if not (path/'units.yaml').exists() or not (path/'meanings.yaml').exists():
    ...
    with open(path/'units.yaml', 'w') as f:
        yaml.dump(units, f)
    with open(path/'meanings.yaml', 'w') as f:
        yaml.dump(meaning, f)

# %%
with open(path/'units.yaml') as f:
    unit_map = yaml.safe_load(f)
unit_map
# Out:
# {'%Good3': '%',
#  '%Good4': '%',
#  '%GoodE': '%',
#  '...>': '...>',
#  'ACCUM': 'mm',
#  'APD': 'sec',
#  'ATMP': 'degC',
#  'BATTCURR': 'Amps',
#  'BATTTEMP': 'DegC',
#  'BATTV': 'Volts',
#  'Bin': '-',
#  'CHILL': 'degC',
#  'CLCON': 'ug/l',
#  'CM1': '-',
#  'CM2': '-',
#  'CM3': '-',
#  'CM4': '-',
#  'COND': 'mS/cm',
#  'DD': 'dy',
#  'DEP01': 'm',
#  'DEP02': 'm',
#  'DEP03': 'm',
#  'DEPTH': 'm',
#  'DEWP': 'degC',
#  'DIR01': 'degT',
#  'DIR02': 'degT',
#  'DIR03': 'degT',
#  'DPD': 'sec',
#  'Depth': 'm',
#  'Dir': 'degT',
#  'EH': 'mv',
#  'EI1': '-',
#  'EI2': '-',
#  'EI3': '-',
#  'EI4': '-',
#  'ErrVl': 'cm/s',
#  'Flags': '-',
#  'GDR': 'degT',
#  'GST': 'm/s',
#  'GTIME': 'hhmm',
#  'HEAT': 'degC',
#  'HEIGHT': 'm',
#  'I': '-',
#  'ICE': 'cm/hr',
#  'LAT': 'deg',
#  'LON': 'deg',
#  'LWRAD': 'w/m2',
#  'MM': 'mo',
#  'MWD': 'degT',
#  'O2%': '%',
#  'O2PPM': 'ppm',
#  'OTMP': 'degC',
#  'PCT': '%',
#  'PH': '-',
#  'PRES': 'hPa',
#  'PTDY': 'hPa',
#  'PTIME': 'hhmm',
#  'RATE': 'mm/h',
#  'REMCAP': 'Ah',
#  'SAL': 'psu',
#  'SDEV': '-',
#  'SPD01': 'cm/s',
#  'SPD02': 'cm/s',
#  'SPD03': 'cm/s',
#  'SRAD1': 'w/m2',
#  'STEEPNESS': '-',
#  'SWRAD': 'w/m2',
#  'Speed': 'cm/s',
#  'SwD': '-',
#  'SwH': 'm',
#  'SwP': 'sec',
#  'T': '-',
#  'TIDE': 'ft',
#  'TURB': 'FTU',
#  'VIS': 'nmi',
#  'VerVl': 'cm/s',
#  'WDIR': 'degT',
#  'WSPD': 'm/s',
#  'WSPD10': 'm/s',
#  'WSPD20': 'm/s',
#  'WTIME': 'hhmm',
#  'WTMP': 'degC',
#  'WVHT': 'm',
#  'WWD': 'degT',
#  'WWH': 'm',
#  'WWP': 'sec',
#  'YY': 'yr',
#  'hh': 'hr',
#  'hhmm': 'hrmn',
#  'mm': 'mn',
#  'ss': 's'}

# %%
with open(path/'meanings.yaml') as f:
    meaning_map = yaml.safe_load(f)
meaning_map
# Out:
# {'': ' Notes:\nThe R1 and R2 values in the monthly and yearly historical data files are scaled by 100, a carryover from how the data are transported to the archive centers. The units are hundredths, so the R1 and R2 values in those files should be multiplied by 0.01.\nD(f,A) can take on negative values because of the trigonometric sine and cosine functions. There are several approaches to prevent or deal with the negative values. For more information and discussion of some approaches see:  Use of advanced directional wave spectra analysis methods, M. D. Earle,  K. E. Steele, and D. W. C. Wang, Ocean Engineering, Volume 26, Issue 12, December 1999, Pages 1421-1434.\nALPHA2 has ambiguous results in using the arctangent function with the Fourier Coefficients,b 2 ,a 2 . When necessary, NDBC adds 180 degrees to ALPHA2 in order to minimize the difference between ALPHA 1 and ALPHA2.\n',
#  '%Good3': 'The percentage of three-beam solutions that are good.',
#  '%Good4': 'The percentage of four-beam solutions that are good.',
#  '%GoodE': 'The percentage of transformations rejected.',
#  '10-Minute Rain Rate': 'Rain rate in units of millimeters per hour on station over the 10-minute period from 5 minutes before to 4 minutes 59.99 seconds after the time with which it is associated.',
#  '24-Hour Rain Rate': 'Average precipitation rate in units of millimeters per hour over 24-hour period from 00:00 to 23:59.99 GMT.',
#  'APD': 'Average Wave Period is the average period (seconds) of the highest\n\t\tone-third of the wave observed during a 20 minute sampling period.',
#  'ATMP': 'Air temperature (Celsius).  For sensor heights on buoys, see\n\t\tHull Descriptions.  For sensor heights at\n\t\tC-MAN stations, see C-MAN Sensor Locations',
#  'BATTCURR': 'Hourly Average Battery Current (amperes)',
#  'BATTTEMP': 'Hourly Average Battery Temperature (degrees Celsius)',
#  'BATTV': 'Hourly Average Battery Voltage (volts)',
#  'Bin': 'The bin number, ranging from 1 to 128, where 1 is the bin closest to the transducer head.',
#  'CHILL': 'Please note that NDBC uses unadjusted winds to calculate wind\n\t\tchill.  The winds are calculated at anemometer height. For more\n\t\tinformation on wind chill, please see the \n\t\tNWS Wind Chill Temperature Index.',
#  'CM1, CM2, CM3, CM4': 'The correlation magnitude values for the four beams.  Valid values are 0 to 255.\n\t\tCM1 = Correlation Magnitude for beam #1;\n\t\tCM2 = Correlation Magnitude for beam #1;\n\t\tCM3 = Correlation Magnitude for beam #3; and\n\t\tCM4 = Correlation Magnitude for beam #4.',
#  'Chlorophyll Concentration (CLCON)': 'Chlorophyll concentration in micrograms per liter (ug/l).',
#  'Conductivity (COND)': 'Conductivity is a measure of the electrical conductivity properties of\n\t\tseawater in milliSiemens per centimeter.',
#  'DEP01, DEP02, ...': 'The distance from the sea surface to the middle of the depth cells,\n\t\tor bins, measured in meters.',
#  'DEWP': 'Dewpoint temperature taken at the same height as the air\n\t\ttemperature measurement.',
#  'DIR': 'Direction the current is flowing TOWARDS, measured in degrees\n\t\tclockwise from North.',
#  'DIR01, DIR02, ...': 'The direction the ocean current is flowing toward.  0-360 degrees,\n\t\t360 is due north, 0 means no measurable current.',
#  'DPD': 'Dominant wave period (seconds) is the period with the maximum wave\n\t\tenergy. See the Wave Measurements section.',
#  'Depth': 'The distance from the sea surface to the middle of the depth cells,\n        or bins, measured in meters.',
#  'Depth (DEPTH)': 'Depth (meters) at which measurements are taken.',
#  'Dir': 'The direction the ocean current is flowing toward.  0-360 degrees,\n\t\t360 is due north, 0 means no measurable current.',
#  'Directional Wave Spectrum': '= C11(f) * D(f,A), f=frequency (Hz), A=Azimuth angle measured\n\t\tclockwise from true North to the direction wave is from.\n\t\tD(f,A) = (1/PI)*(0.5+R1*COS(A-ALPHA1)+R2*COS(2*(A-ALPHA2))).  \n\t\tR1 and R2 are the first and second normalized polar coordinates of the Fourier coefficients and are nondimensional. ALPHA1 and ALPHA2 \n\t\tare respectively mean and principal wave directions.In terms of\n\t\tLonguet-Higgins Fourier Coefficients\nR1 = (SQRT(a1*a1+b1*b1))/a0\nR2 = (SQRT(a2*a2+b2*b2))/a0\nALPHA1 = 270.0-ARCTAN(b1,a1)\nALPHA2 = 270.0-(0.5*ARCTAN(b2,a2)+{0. or 180.})',
#  'EI1, EI2, EI3, EI4': 'The echo intensity values for the four beams.  Valid values are 0 to 255.\n\t\tEI1 = Echo Intensity for beam #1;\n\t\tEI2 = Echo Intensity for beam #1;\n\t\tEI3 = Echo Intensity for beam #3; and\n\t\tEI4 = Echo Intensity for beam #4.',
#  'Eh (EH)': 'Redox (oxidation and reduction) potential of seawater in millivolts.',
#  'ErrVl': 'The error velocity measured in cm/s.',
#  'Flag': 'In the case of 10-minute rainfall measurements, a flag is assigned to any measurement when either the -5 or +5 minute rain measurement from which it is derived is missing or obviously an error.',
#  'Flags': 'The nine quality flags represent the results of the following quality tests based on their position in the flags field.\nFlag 1 represents the overall bin status.\n\t\tFlag 2 represents the ADCP Built-In Test (BIT) status.\n\t\tFlag 3 represents the Error Velocity test status.\n\t\tFlag 4 represents the Percent Good test status.\n\t\tFlag 5 represents the Correlation Magnitude test status.\n\t\tFlag 6 represents the Vertical Velocity test status.\n\t\tFlag 7 represents the North Horizontal Velocity test status.\n\t\tFlag 8 represents the East Horizontal Velocity test status.\n\t\tFlag 9 represents the Echo Intensity test status.\nValid values are:\n\t\t0 = quality not evaluated;\n\t\t1 = failed quality test;\n\t\t2 = questionable or suspect data;\n\t\t3 = good data/passed quality test; and\n\t\t9 = missing data.',
#  'GDR': 'Direction, in degrees clockwise from true North, of the GST,\n\t\treported at the last hourly 10-minute segment.',
#  'GST': 'Maximum 5-second peak gust during the measurement hour, reported at\n\t\tthe last hourly 10-minute segment.',
#  'GTIME': 'The minute of the hour that the GSP occurred, reported at the last\n\t\thourly 10-minute segment.',
#  'HEAT': 'For more information on heat index, please see the\n\t\tNWS Heat Wave page.',
#  'HEIGHT': 'Height of water column in meters.',
#  'Highest 1 minute wind speed': 'Highest recorded wind speed for the hour to the nearest 0.1 m/s, its corresponding direction to the nearest degree, and the time at which it occurred (hour and minute).',
#  'Hourly Rain Accumulation': 'Total accumulation of precipitation in units of millimeters on station during the 60-minute period from minute 0 to minute 59:59.99 of the hour.',
#  'ICE': 'Estimated ice accretion in inches per hour based on an\n\t\talgorithm developed by Overland and Pease at the Pacific Marine\n\t\tEnvironmental Laboratory in the mid-1980s. The algorithm relates icing\n\t\tto the presently observed wind speed, air temperature, and sea surface\n\t\ttemperature.  The method is designed for trawlers in the 20 to 75 meter \n\t\tlength range, underway at normal speeds in open seas and not heading \n\t\tdownwind. In general, NWS forecasters translate ice accretion rates to the \n\t\tfollowing categories:\nlight: 0.0 to 0.24 inches of ice accretion/hour;\nmoderate: 0.25 to 0.8 inches/hour; and\nheavy: greater than 0.8 inches/hour.',
#  'Instrument Number': 'Stations may have more than one ADCP instrument.  This field distinguishes these instruments by number.  Valid values are 0-9, with 0 being reserved for surface measurements.',
#  'LAT': 'Latitude in decimal degrees at which observation was taken.\n\t\tPositive values represent norhtern hemisphere while negatvie values\n\t\trepresent southern hemisphere.\n\t\t',
#  'LON': 'Longitude in decimal degrees at which observation was taken.\n\t\tPositive values represent eastern hemisphere while negatvie values\n\t\trepresent western hemisphere.\n\t\t',
#  'Longwave Radiation (LWRAD)': 'Average downwelling longwave radiation in watts per\n\t\tsquare meter for the preceding hour.  Sample frequency is 2 times per\n\t\tsecond (2 Hz).  If present, LWRAD is from an Eppley PIR Precision\n\t\tInfrared Radiometer.',
#  'Lowest 1 minute pressure': 'Lowest recorded atmospheric pressure for the hour to the nearest 0.1 hPa and the time at which it occurred (hour and minute).',
#  'MWD': 'The direction from which the waves at the dominant period (DPD) are \n\t\tcoming. The units are degrees from true North, increasing clockwise, with \n\t\tNorth as 0 (zero) degrees and East as 90 degrees.  \n\t\tSee the Wave Measurements section.',
#  'Ocean Temperature (OTMP)': 'The direct measurement (Celsius) of the Ocean Temperature (as opposed\n\t\tto the indirect measurement  (see WTMP above)).',
#  'Oxygen Concentration (O2%)': 'Dissolved oxygen as a percentage.',
#  'Oxygen Concentration (O2PPM)': 'Dissolved oxygen in parts per million.',
#  'PRES': 'Sea level pressure (hPa).  For C-MAN sites and Great Lakes buoys,\n\t\tthe recorded pressure is reduced to sea level using the method\n\t\tdescribed in NWS Technical Procedures Bulletin 291 (11/14/80). (\n\t\tlabeled BAR in Historical files)',
#  'PTDY': 'Pressure Tendency is the direction (plus or minus) and the amount of\n\t\tpressure change (hPa)for a three hour period ending at the time of\n\t\tobservation. (not in Historical files)',
#  'Percent Time Raining in 24-Hour Period': 'Percentage of 144 ten-minute periods within a 24 hour period with a measurable accumulation of precipitation.',
#  'REMCAP': 'Remaining Battery Capacity (ampere-hours)',
#  'SDev': '---',
#  'SPD': 'Current speed in cm/s.',
#  'SPD01, SPD02, ...': 'The speed of the ocean current measured in cm/s.',
#  'STEEPNESS': 'Wave steepness is the ratio of wave height to wave length and is an\n\t\tindicator of wave stability.  When wave steepness exceeds a 1/7 ratio;\n\t\tthe wave becomes unstable and begins to break.',
#  'Salinity (SAL)': 'Salinity is computed by a known functional relationship between the\n\t\tmeasured electrical conductivity of seawater (CON), temperature (OTMP) and\n\t\tpressure. Salinity is computed using the Practical Salinity Scale of 1978\n\t\t(PSS78) and reported in Practical Salinity Units.',
#  'Sep_Freq': 'The Separation Frequency is the frequency that separates wind waves (WWH, WWP, WWD)\n\t\tfrom swell waves (SWH, SWP,SWD). NDBC inserts the value 9.999 if  Sep_Freq is missing.',
#  'Shortwave Radiation(SRAD1, SWRAD)': 'Average shortwave radiation in watts per square\n\t\tmeter for the preceding hour. Sample frequency is 2 times per second (2\n\t\tHz).   If present, SRAD1 is from a LI-COR LI-200 pyranometer sensor, and\n\t\tSWRAD is from an Eppley PSP Precision Spectral Pyranometer.',
#  'Spectral wave density': 'Energy in (meter*meter)/Hz, for each frequency bin (typically from\n\t\t0.03 Hz to 0.40 Hz).',
#  'Spectral wave direction': 'Mean wave direction, in degrees from true North, for each frequency\n\t\tbin. A list of directional stations is available.',
#  'Speed': 'The speed of the ocean current measured in cm/s.',
#  'SwD': 'The direction from which the swell waves at the swell wave \n\t\tperiod (SWPD) are coming.  The units are degrees from true North, \n\t\tincreasing clockwise, with North as 0 (zero) degrees and East as 90 \n\t\tdegrees.',
#  'SwH': 'Swell height is the vertical distance (meters) between any swell\n\t\tcrest and the succeeding swell wave trough.',
#  'SwP': 'Swell Period is the time (usually measured in seconds) that it takes\n\t\tsuccessive swell wave crests or troughs pass a fixed point.',
#  'T (TYPE)': 'Measurement Type:\n1 = 15-minute measurement;\n2 = 1-minute measurement; and\n3 = 15-second measurement.',
#  'TG01, TG02, ..., TG10': 'Six-minute water levels representing the height, in feet, of the\n\t\twater above or below Mean Lower Low Water (MLLW),\n\t\toffset by 10 ft. to prevent negative values.   Please subtract 10\n\t\tft. from every value to obtain the true water level value, in reference to MLLW.',
#  'TIDE': 'The water level in feet above or below Mean Lower Low Water (MLLW). \n\t\t',
#  'Turbidity (TURB)': 'Turbidity is an expression of the optical property that causes light to\n\t\tbe scattered and absorbed rather than transmitted in straight lines through\n\t\tthe sample (APHA 1980). Units are Formazine Turbidity Units (FTU).',
#  'VIS': 'Station visibility (nautical miles). Note that buoy stations are limited to reports from 0 to 1.6 nmi.',
#  'VerVl': 'The vertical velocity of the ocean current measured in cm/s.',
#  'WDIR': 'Ten-minute average wind direction measurements in degrees clockwise\n\t\tfrom true North. (DIR in Historical files)',
#  'WSPD': 'Ten-minute average wind speed values in m/s. (SPD in Historical files)',
#  'WSPD10': 'The estimation of Wind Speed (WSPD) measurement raised or lowered to a height\n    of 10 meters. NDBC uses the method of Liu et al., 1979: Bulk parameterization\n    of air-sea exchanges in heat and water vapor including molecular constraints at\n    the interface, Journal of Atmospheric Science, 36, pp. 1722-1735.',
#  'WSPD20': 'The estimation of Wind Speed (WSPD) measurement raised or lowered to a height\n    of 20 meters. NDBC uses the method of Liu et al., 1979: Bulk parameterization\n    of air-sea exchanges in heat and water vapor including molecular constraints at\n    the interface, Journal of Atmospheric Science, 36, pp. 1722-1735.',
#  'WTMP': "Sea surface temperature (Celsius). For buoys the depth is referenced\n\t\tto the hull's waterline. For fixed platforms it varies with tide, but is\n\t\treferenced to, or near Mean Lower Low Water (MLLW).",
#  'WVHT': 'Significant Wave Height is the average height (meters) of the\n\t\thighest one-third of the waves during a 20 minute sampling period.',
#  'WWD': 'The direction from which the wind waves at the wind wave period (WWPD)\n\t\tare coming.  The units are degrees from true North, increasing clockwise, \n\t\twith North as 0 (zero) degrees and East as 90 degrees.',
#  'WWH': 'Wind Wave Height is the vertical distance (meters) between any wind\n\t\twave crest and the succeeding wind wave trough (independent of swell\n\t\twaves).',
#  'WWP': 'Wind Wave Period is the time (in seconds) that it takes successive\n\t\twind wave crests or troughs to pass a fixed point.',
#  'pH (PH)': 'A measure of the acidity or alkalinity of the seawater.'}

# %% [markdown]
# You may want to concatenate each buoy's data into a single dataframe, or any other data structure that you see fit. `pandas` is recommended here for your convenience.

# %% [markdown]
# After plotting, you will notice that some values are saturated at ~100. This is considered as artifacts, and should be removed. We will filter out everything $\ge 90$ in this case. If you are using `pandas`, you can do something like `df[df[columns] < 90]`.
# Also, remove all rows with `NaN` values.

# %%
# ================ INSERT YOUR CODE HERE ================

# Concatenate the data of each Buoy 

for fldr in [p for p in Path('./Data').iterdir() if p.is_dir()]:
    if Path(f'./{fldr}/merged_data.csv').exists():
        continue
    csv_files = glob.glob(f'./{fldr}/*.csv')
    if csv_files: 
        data_frame = pd.concat(map(pd.read_csv, csv_files), ignore_index=True)
        for column in head_columns[5:]:
            data_frame = data_frame[data_frame[column] < 90 ]
            data_frame = data_frame[data_frame[column] != 'NaN']
        data_frame.to_csv(f'./{fldr}/merged_data.csv',index=False)

# %% [markdown]
# As python handles datetime objects in fundamentally nasty way, we provide a snippet to convert YMDhm to datetime objects for you. You can use it like this:
#
# ```python
# YMDhm = df[['#YY','MM','DD','hh','mm']]
# timestemp = YMDhm.agg(lambda x: datetime(*x), axis=1)
# ```
#
# to get a series of datetime objects from the dataframe `df` with columns `#YY`, `MM`, `DD`, `hh`, and `mm`.

# %% [markdown]
# #### For one buoy, plot all of its columns from all last 10 years. You can use any plotter of your choice.
# ##### Can you see any trend? If it is too noisy for human eyes, what could to be done to make it more clear?

# %% [markdown]
# ##### Launch `scipy.stats` and choose something like Pearson's or Spearman's correlation test. Determine what (if any) correlations you find between mean ocean temperatures and maximum wave heights or wave periods.|

# %%
# ================ INSERT YOUR CODE HERE ================
        
# DATA VISUALIZATION

# Getting the timestamps for each file
for fldr in [p for p in Path('./Data').iterdir() if p.is_dir()]:
    csv_file = open(f'./{fldr}/merged_data.csv','r')
    reader = csv.reader(csv_file)
    header = next(reader)
    timestamps = []
    for row in reader:
        time_str = ''
        for time in row[:5]:
            time_str += time + '-'
        timestamp = datetime.strptime(time_str, '%Y-%m-%d-%H-%M-') 
        timestamps.append(timestamp)
    csv_file.close()

    # Plotting each column and saving it in a jpg file
    for column in head_columns[5:]:
        if Path(f'./{fldr}/{str(fldr)[-5:]}_{column}.jpg').exists():
            continue
        df = pd.read_csv(f'./{fldr}/merged_data.csv')
        saved_column = df[column].tolist()
        plt.figure(figsize=(21,14))  
        plt.scatter(timestamps,saved_column,color='blue',edgecolor='none',s=2)
        plt.title(f'Buoy ID: {str(fldr)[-5:]}',fontsize=14)
        plt.xticks(rotation=45,fontsize=9)
        plt.xlabel('Time (year)',fontsize=14)
        plt.ylabel(f'{column} ({units[column]})',fontsize=18)
        plt.tick_params(axis='both',which='major',labelsize=18)
        plt.savefig(f'./{fldr}/{str(fldr)[-5:]}_{column}.jpg',bbox_inches='tight')
        plt.clf()
        plt.close()

    # Pearson's test
    df = pd.read_csv(f'./{fldr}/merged_data.csv')
    temp_column = df['WTMP'].tolist()
    for column in head_columns[6:8]:
        test_column = df[column].tolist()
        corr, p_value = pearsonr(temp_column, test_column)
        with open(f'./{fldr}/pearson_results.txt','a') as test:
            test.write(f'Pearson\'s test result for WTMP-{column}:\n' + 'Correlation Coefficient: '+str(corr)
                       +'\n'+'Statistical Significance: ' +str(p_value)+'\n')
